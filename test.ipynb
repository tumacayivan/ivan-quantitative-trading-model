# %%
import os
from openai import OpenAI

# ⚠️ Replace with your NEW key (do NOT reuse the one you posted)
client = OpenAI(api_key="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")

try:
    response = client.responses.create(
        model="gpt-4.1-mini",
        input="Hello, just testing if my API key works."
    )
    print("✅ API key is working!")
    print(response.output[0].content[0].text)

except Exception as e:
    print("❌ API key failed:")
    print(e)
# Out:
# ❌ API key failed:
# Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
